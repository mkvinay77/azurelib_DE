# %%
# Imagine that you are bulding the zomato app. It has the functionality to add the item
# in the cart. AS soon as item get added up in the cart, I want 
#


#

# %%
item1 = 100
item2 = 200
item3 = 400
sum = item_1 + item_2 + item_3
print (sum)

# %%
item1 = 100
item2 = 200
item3 = 400
sum = item_1 + item_2 + item_3
print (sum)
tax = (sum * 10)/100
total = sum + tax
print (total)

# %%
item1 = 100
item2 = 200
item3 = 400
sum = item_1 + item_2 + item_3
print (sum)
tax = (sum * 10)/100
total = sum + tax
print (total)

if sum < 1000:
    tax = (sum * 10)/100
    total = sum + tax
    print (total)
else:
    total = sum
    print (total)

# %%
# Imagine that you are going for a movie Dhurader. you and your spouse and along with two kids.
#one is 12 years old and another one is

# %%
Husband = 150
wife = 150
child1 = 100
child2 = 0
sum = Husband + wife + child1 + child2
print (sum)

# %%
p1 = 20
p2 = 20
p3 = 10
p4 = 0

ticketCost = 0
if p1 >= 20:
    ticketCost = ticketCost + 150
if p2 >= 20:
    ticketCost = ticketCost + 150
if p3 >= 10:
    ticketCost = ticketCost + 100
if p4 < 10:
    ticketCost = ticketCost + 0
else:
    ticketCost = ticketCost

print (ticketCost)

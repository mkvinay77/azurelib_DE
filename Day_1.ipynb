# %%
# Case 1) Imagine that you are bulding the zomato app. It has the functionality to add the item
# in the cart. AS soon as item get added up in the cart, I want you yo print the
#total amount to pay in the bottom.

#case 2)

# %%
item1 = 100
item2 = 200
item3 = 400
sum = item1 + item2 + item3
print ("The grand toatl is 🎉", sum)

# %%
# Case 1) Imagine that you are bulding the zomato app. It has the functionality to add the item
# in the cart. AS soon as item get added up in the cart, I want you yo print the
# total amount to pay in the bottom.

# case 2) New changes: Tax as it is holiday session, add holiday over load Tax = 10% of the total sum
#For example: item1 = 100, item2 = 200, item3=400 then answer is = 770

# %%
item1 = 100
item2 = 200
item3 = 400
sum = item1 + item2 + item3
#print (sum)
tax = (sum * 10)/100
total = sum + tax
print ("The grand total including the tax is☝️",total)

# %%
# case 3) if your amount is more than 1000 rs there is no tax.
# a) item1 = 100, item2 = 200, item3=400
# b) item1 = 1000, item2 = 200, item3=400

# %%
item1 = 100
item2 = 200
item3 = 400
sum = item1 + item2 + item3
#print (sum)
#tax = (sum * 10)/100
#total = sum + tax
#print (total)
total = 0

if sum < 1000:
    tax = (sum * 10)/100
    total = sum + tax
    print (total)
else:
    total = sum
    print (total)

# %%
item1 = 1000
item2 = 200
item3 = 400
sum = item1 + item2 + item3
total = 0

if sum < 1000:
    tax = (sum *10)/100
    total = sum + tax
    print("The grand total including the tax is☝️",total)
else:
    total = sum
    print("The grand total is without tax is🙌",total)

# %%
# Imagine that you are going for a movie Dhurader. you and your spouse and along with two kids.
#one is 12 years old and another one is 5 year old.
#For adults it is 150 rupees per person
#For minor (above 10 years old) : 100 rupees per person
#For kids (below 10 years old) : 0 rupees or free

# %%
Husband = 150
wife = 150
child1 = 100
child2 = 0
sum = Husband + wife + child1 + child2
print ("The total amount of ticket is", sum)

# %%
p1 = 20
p2 = 20
p3 = 10
p4 = 0

ticketCost = 0
if p1 >= 20:
    ticketCost = ticketCost + 150
if p2 >= 20:
    ticketCost = ticketCost + 150
if p3 >= 10:
    ticketCost = ticketCost + 100
if p4 < 10:
    ticketCost = ticketCost + 0
else:
    ticketCost = ticketCost

print (ticketCost)

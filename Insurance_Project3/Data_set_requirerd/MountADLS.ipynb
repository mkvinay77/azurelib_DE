# %% [markdown]
# #Mounting the bronzelayer continar

# %%
# Container name = bronzelayer
# Stoage account name = smartpolicysystemadls
# Storage account SAS token = sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupyx&se=2026-04-11T11:01:15Z&st=2026-03-18T02:46:15Z&spr=https&sig=gmlIWlYg%2FfgOeoEa3zGY9uGAdW3ThApb%2BZENOI8eVMo%3D

# DBFS mounts are disabled on this workspace.
# Using direct access via spark.conf.set instead.

spark.conf.set(
    'fs.azure.sas.bronzelayer.smartpolicysystemadls.blob.core.windows.net',
    'sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupyx&se=2026-04-11T11:01:15Z&st=2026-03-18T02:46:15Z&spr=https&sig=gmlIWlYg%2FfgOeoEa3zGY9uGAdW3ThApb%2BZENOI8eVMo%3D'
)

# Access files using the full path:
# wasbs://bronzelayer@smartpolicysystemadls.blob.core.windows.net/<your-file>

# %%
# %fs
ls wasbs://bronzelayer@smartpolicysystemadls.blob.core.windows.net/

# %%
# List files and folders in the ADLS container
files = dbutils.fs.ls('wasbs://bronzelayer@smartpolicysystemadls.blob.core.windows.net/')
display(files)

# %% [markdown]
# #Mounting Landing continar

# %%
# Container name = bronzelayer
# Stoage account name = smartpolicysystemadls
# Storage account SAS token = sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupyx&se=2026-04-11T11:01:15Z&st=2026-03-18T02:46:15Z&spr=https&sig=gmlIWlYg%2FfgOeoEa3zGY9uGAdW3ThApb%2BZENOI8eVMo%3D

# DBFS mounts are disabled on this workspace.
# Using direct access via spark.conf.set instead.

spark.conf.set(
    'fs.azure.sas.landing.smartpolicysystemadls.blob.core.windows.net',
    'sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupyx&se=2026-04-11T11:01:15Z&st=2026-03-18T02:46:15Z&spr=https&sig=gmlIWlYg%2FfgOeoEa3zGY9uGAdW3ThApb%2BZENOI8eVMo%3D'
)

# Access files using the full path:
# wasbs://bronzelayer@smartpolicysystemadls.blob.core.windows.net/<your-file>

# %%
# %fs
ls wasbs://landing@smartpolicysystemadls.blob.core.windows.net/

# %% [markdown]
# #Mounting processed Continar

# %%
spark.conf.set(
    'fs.azure.sas.processed.smartpolicysystemadls.blob.core.windows.net',
    'sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupyx&se=2026-04-11T11:01:15Z&st=2026-03-18T02:46:15Z&spr=https&sig=gmlIWlYg%2FfgOeoEa3zGY9uGAdW3ThApb%2BZENOI8eVMo%3D'
)

# %%
# %fs
ls wasbs://processed@smartpolicysystemadls.blob.core.windows.net/

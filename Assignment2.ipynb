# %% [markdown]
# <a href="https://colab.research.google.com/github/mkvinay77/azurelib_DE/blob/main/Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Q1:
# Movie Ticket Pricing
# Scenario: A cinema has different ticket prices based on age.
# Task: Write a program that asks for the customer's age and prints the ticket price.

# Child (0-12): ₹100
# Teen (13-17): ₹150
# Adult (18-59): ₹200
# Senior (60+): ₹120

age = int(input("Enter the age :: "))

if age <= 12:
  price = 100
elif age >=13 and age <=17:
  price = 150
elif age >=18 and age <=59:
  price = 200
else:
  price = 120

print("The price of ticket is =",price)
# Out:
# Enter the age :: 45
# The price of ticket is = 200

# %%
# Q2:
# Simple Weather Advisory
# Scenario: A local weather station provides basic weather advisories.
# Task: Create a program that takes the current temperature (in Celsius) and provides an appropriate advisory.

# Below 0: "It's freezing! Wear warm layers."
# 0-10: "It's very cold. Wear a heavy jacket."
# 11-20: "It's cool. A light jacket would be good."
# 21-30: "It's pleasant. Enjoy the weather!"
# Above 30: "It's hot. Stay hydrated!"


Temp_Celsius = int(input("Enter the Temp in Celsius 🌡️:: "))

if Temp_Celsius < 0:
  weather = "It's freezing! Wear warm layer❄️"
elif Temp_Celsius >= 0 and Temp_Celsius <= 10:
  weather = "It's very cold Wear a heavy jacket 🥶"
elif Temp_Celsius >= 11 and Temp_Celsius <= 20:
  weather = "It's cool A light jacket would be good🙌."
elif Temp_Celsius >=21 and Temp_Celsius <=30:
  weather = "It's pleasant Enjoy the weather!😍"
else:
  weather = "It's hot Stay hydrated!🫗🥤"

print("The weather is =",weather)
# Out:
# Enter the Temp in Celsius 🌡️:: 42
# The weather is = It's hot Stay hydrated!🫗🥤

# %%
# Q3:
# Restaurant Tip Calculator
# Scenario: A restaurant suggests tips based on service quality.
# Task: Write a program that asks for the bill amount and service quality (Excellent, Good, Fair, Poor) and calculates the suggested tip.

# Excellent: 20% tip
# Good: 15% tip
# Fair: 10% tip
# Poor: 5% tip

#Scaling = Excellent, Good, Fair, Poor)

print ("The Sacling in Excellent, Good, Fair, Poor")
service_quality = input("Enter the service qaulity = ")

if service_quality == 'Excellent':
  tip = 20
elif service_quality =='Good':
  tip = 15
elif service_quality == 'Fair':
  tip = 10
elif service_quality == 'Poor':
  tip = 5
else:
  tip = 0

print("The tip for the service = ", tip,"%")
# Out:
# The Sacling in Excellent, Good, Fair, Poor
# Enter the service qaulity = Poor
# The tip for the service =  5 %

# %%
# Q5:
# Blood Donation Eligibility
# Scenario: A blood donation camp screens donors based on basic criteria.
# Task: Write a program that determines if a person is eligible to donate blood based on:

# Age (must be 18-65)
# Weight (must be above 50 kg)
# Last donation (must be more than 3 months ago)

Age = int(input("Enter the Age = "))
Weight = int(input("Enter the weight = "))
Last_donation = int(input("Enter the last donation months in number = "))

if Age >=18 and Age <= 65 and Weight > 50 and Last_donation > 3:
  print ("Finally your are eligble for blood donation 💪")
else:
  print("Sorry you are not eligble for blood donation 😅")
# Out:
# Enter the Age = 40
# Enter the weight = 55
# Enter the last donation months in number = 4
# Finally your are eligble for blood donation 💪

# %%
Age = int(input("Enter the Age = "))
Weight = int(input("Enter the weight = "))
Last_donation = int(input("Enter the last donation months in number = "))

if Age >=18 and Age <= 65 and Weight > 50 and Last_donation > 3:
  print ("Finally your are eligble for blood donation")
else:
  print("Sorry you are not eligble for blood donation")
# Out:
# Enter the Age = 17
# Enter the weight = 51
# Enter the last donation months in number = 4
# Sorry you are not eligble for blood donation

# %%
# Q6:
# Simple Car Insurance Premium Estimator
# Scenario: A car insurance company determines premiums based on driver's age and car type.
# Task: Create a program that estimates the premium:

# Age below 25: High risk
# Age 25-40: Medium risk
# Age above 40: Low risk
# Car types: Economy, Sedan, Luxury (increasing premiums in that order)

age = int(input("Enter the age: "))
car_type = input("Enter the car type (Economy/Sedan/Luxury): ")

# Determine risk based on age
if age < 25:
    risk = "High risk"
elif 25 <= age <= 40:
    risk = "Medium risk"
else:
    risk = "Low risk"

# Determine premium based on car type
if car_type.lower() == "economy":
    premium = "Low premium"
elif car_type.lower() == "sedan":
    premium = "Medium premium"
elif car_type.lower() == "luxury":
    premium = "High premium"
else:
    premium = "Unknown premium (invalid car type)"

print(f"Risk Level: {risk}")
print(f"Premium Category: {premium}")
# Out:
# Enter the age: 25
# Enter the car type (Economy/Sedan/Luxury): sedan
# Risk Level: Medium risk
# Premium Category: Medium premium

# %%
age = int(input("Enter the age: "))
car_type = input("Enter the car type (Economy/Sedan/Luxury): ")

# Determine risk based on age
if age < 25:
    risk = "High risk"
elif 25 <= age <= 40:
    risk = "Medium risk"
else:
    risk = "Low risk"

# Determine premium based on car type
if car_type.lower() == "economy":
    premium = "Low premium"
elif car_type.lower() == "sedan":
    premium = "Medium premium"
elif car_type.lower() == "luxury":
    premium = "High premium"
else:
    premium = "Unknown premium (invalid car type)"

print("Risk Level :", risk)
print("Premium Category :", premium)
# Out:
# Enter the age: 60
# Enter the car type (Economy/Sedan/Luxury): luxury
# Risk Level : Low risk
# Premium Category : High premium

# %%
# Q7:
# ollege Admission Predictor
# Scenario: A college has different admission criteria based on exam scores.
# Task: Write a program that predicts admission chances based on exam score:

# Below 60: "Admission unlikely"
# 60-79: "Admission possible"
# 80-89: "Admission probable"
# 90 and above: "Admission assured"

score = int(input("Enter the score of the exam = "))

if score < 60:
  result = "Admission unlikely"
elif score >= 60 and score <= 79:
  result = "Admission possible"
elif score >= 80 and score <= 89:
  result = "Admission probable"
elif score >= 90:
  result = "Admission assured"

print("Your seat is = ", result)
# Out:
# Enter the score of the exam = 91
# Your seat is =  Admission assured

# %%
# Q8:
# Simple Loan Approval System
# Scenario: A bank has basic criteria for loan approval.
# Task: Create a program that determines loan approval based on:

# Credit Score (Good/Fair/Poor)
# Annual Income (Above/Below ₹500,000)
# Employment Status (Employed/Self-employed/Unemployed)

credit_score = input("Enter your credit score (Good/Fair/Poor) :").lower()
annual_income = int(input("Enter your Annual Income :"))
employment_status = input("Employment Status (Employed/Self-employed/Unemployed):").lower()


if credit_score == "good" and annual_income >= 500000 and employment_status != "unemployed":
    result = "Loan Approved"
elif credit_score == "fair" and annual_income >= 500000 and employment_status != "unemployed":
    result = "Loan Approved with Conditions"
else:
    result = "Loan Rejected"

print("Loan Status:", result)
# Out:
# Enter your credit score (Good/Fair/Poor) :good
# Enter your Annual Income :500000
# Employment Status (Employed/Self-employed/Unemployed):employed
# Loan Status: Loan Approved

# %%
# Q9:
# Mobile Plan Recommender
# Scenario: A telecom company recommends plans based on usage.
# Task: Write a program that suggests a plan based on monthly data usage:

# 0-2 GB: "Basic Plan"
# 2-5 GB: "Standard Plan"
# 5-10 GB: "Heavy User Plan"
# Above 10 GB: "Unlimited Plan"

data_usage = int(input("Enter the data usage in GB : "))

if 0 <= data_usage <= 2:
    plan = "Basic Plan"
elif 2 < data_usage <= 5:
    plan = "Standard Plan"
elif 5 < data_usage <= 10:
    plan = "Heavy User Plan"
else:
    plan = "Unlimited Plan"

print("Your suitable plan is =", plan)
# Out:
# Enter the data usage in GB : 0
# Your suitable plan is = Basic Plan

# %%
# Q10:
# Simple Health Risk Assessment
# Scenario: A health app provides basic risk assessment based on BMI.
# Task: Create a program that calculates BMI (weight in kg / (height in m)^2) and provides a health risk assessment:

# Below 18.5: "Underweight"
# 18.5-24.9: "Normal weight"
# 25-29.9: "Overweight"
# 30 and above: "Obese"

weight = float(input("Enter the weight in kg : :"))
height = float(input("Enter the height in m : :"))
BMI = (weight / (height **2))

if BMI < 18.5:
    print("Underweight")
elif 18.5 <= BMI <= 24.9:
    print("Normal weight")
elif 25 <= BMI <= 29.9:
    print("Overweight")
else:
    print("Obese")
# Out:
# Enter the weight in kg : :71
# Enter the height in m : :1.75
# Normal weight

# %%
weight = float(input("Enter the weight in kg : :"))
height = float(input("Enter the height in m : :"))
BMI = (weight / (height **2))
# Below 18.5: "Underweight"
# 18.5-24.9: "Normal weight"
# 25-29.9: "Overweight"
# 30 and above: "Obese"

if BMI < 18.5:
  print("Underweight")
elif BMI >= 18.5 and BMI <= 24.9:
  print("Normal weight")
elif BMI >= 25 and BMI <= 29.9:
  print("Overweight")
else:
  print("Obese")

# %% [markdown]
# <a href="https://colab.research.google.com/github/mkvinay77/azurelib_DE/blob/main/day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Imagin that u are working in TCS and it is time apprasial.
#If you have rating 5 then u will get 15% hike.
#If you have rating 4 then u will get 10% hike.
#If you have rating 3 then u will get 5% hike.
##If you have rating below 3 then u will get 0% hike.
#Assume your CTC is 15 LPA tell me your new CTC appraisal assume you got
#3 rating

# %%
current_CTC = 1500000
rating = 3
hike_precent = 0

if rating == 5:
  hike_precent = 15
  print("No")
if rating == 4:
  hike_precent = 10
  print("No")
if rating == 3:
  hike_precent = 5
  New_CTC = current_CTC + (current_CTC*hike_precent)/100


print("Your new CTC =",New_CTC)
# Out:
# Your new CTC = 1575000.0

# %%
#Imagin that u are working in TCS and it is time apprasial.
#If you have rating 5 then u will get 15% hike.
#If you have rating 4 then u will get 10% hike.
#If you have rating 3 then u will get 5% hike.
##If you have rating below 3 then u will get 0% hike.

# Change of CEO: If you are 5 rating person then you get additional one time bonus of 100000
#Assume your CTC is 15 LPA tell me your new CTC appraisal assume you got
#5 rating
current_CTC = 1500000
rating = 5
hike_precent = 0
bonus = 0

if rating == 5:
  hike_precent = 15
  hike_precent = 5
  bonus = 100000
if rating == 4:
  hike_precent = 10
  print("No")
if rating == 3:
  hike_precent = 5
  print("No")

New_CTC = current_CTC + (current_CTC*hike_precent)/100 + bonus
print("Your revised CTC =",New_CTC)
# Out:
# Your revised CTC = 1675000.0

# %%
#Imagin that u are working in TCS and it is time apprasial.
#If you have rating 5 then u will get 15% hike.
#If you have rating 4 then u will get 10% hike.
#If you have rating 3 then u will get 5% hike.
##If you have rating below 3 then u will get 0% hike.

# Change of CEO: If you are 5 rating person then you get additional one time bonus of 100000
# CEO: If you are star performer with rating 5 and if your total work is above 10 year



current_CTC = 1500000
rating = 5
yrs = 10

hike_precent = 0
bonus = 0
extra = 0



if rating == 5:
  hike_precent = 5
  bonus = 100000
  if yrs >= 10:
    extra = 50000
if rating == 4:
  hike_precent = 10
  print("No")
if rating == 3:
  hike_precent = 5
  print("No")
New_CTC = current_CTC + (current_CTC*hike_precent)/100 + bonus + extra
print("Your revised CTC =",New_CTC)
# Out:
# Your revised CTC = 1725000.0

# %%
current_CTC = 1500000
rating = 5
hike_precent = 0
bonus = 0



extraBounus=0


if rating == 5:
  hike_precent = 15
  hike_precent = 5
  bonus = 1
  if yrs = 10
  extraBounus = 50000

if rating == 4:
  hike_precent = 10
  print("No")
if rating == 3:
  hike_precent = 5

# %%
#Imagin that u are working in TCS and it is time apprasial.
#If you have rating 5 then u will get 15% hike.
#If you have rating 4 then u will get 10% hike.
#If you have rating 3 then u will get 5% hike.
##If you have rating below 3 then u will get 0% hike.

# Change of CEO: If you are 5 rating person then you get additional one time bonus of 100000
#CEO
#then

#CEO: If you are low perfomer

#CEO: For all we are puting up 2% education cess deduction as per the
#government norms

#CEO : For those who are getting rating above 3 and have assoicated with organization
#for more than 3 years get the loyalty bonus of 1 lac rupees

#Assume your CTC is 15 LPA tell me your new CTC appraisal assume you got
#5 rating

# %%
#loops
# Take 5 input from the uset and display it one by one

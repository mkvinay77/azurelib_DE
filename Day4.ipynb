# %% [markdown]
# <a href="https://colab.research.google.com/github/mkvinay77/azurelib_DE/blob/main/Day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = []
y = [1,2,3,4,5]

print(type(x))
print(type(y))
print(len(y))
# Out:
# <class 'list'>
# <class 'list'>
# 5

# %%
y = [10,20,30,40,50]
y.append (60)

# %%
y = [10,20,30,40,50]
y.insert(0,5)
print(y)
# Out:
# [5, 10, 20, 30, 40, 50]

# %%
y.pop()
print(y)
# Out:
# [5, 10, 20, 30, 40]

# %%
y = [10,20,30,40,50]
y.pop(0)
print(y)
# Out:
# [20, 30, 40, 50]

# %%
y = [10,20,30,40,50]
y.remove(10)
print(y)
# Out:
# [20, 30, 40, 50]

# %%
y = [10,20,30,40,50]
print(y[0])
print(y[1])
print(y[2])
print(y[3])
print(y[4])
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
y = [10,20,30,40,50]

i = 0
while i < len(y):
  print(y)
  i =i+1
# Out:
# [10, 20, 30, 40, 50]
# [10, 20, 30, 40, 50]
# [10, 20, 30, 40, 50]
# [10, 20, 30, 40, 50]
# [10, 20, 30, 40, 50]

# %%
for i in y:
  print(i)
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
#Imagine that you are working as developer at Zomato.
#Ask the user to enter the item to add to the cart
# Take 5 items from the user.
#at the end dispaly all those five items

items = []
for i in range(5):
  item = input("Enter the item in the cart = ")
  items.append(item)

for i in items:
  print(i)
# Out:
# Enter the item in the cart = a
# Enter the item in the cart = b
# Enter the item in the cart = c
# Enter the item in the cart = d
# Enter the item in the cart = e
# a
# b
# c
# d
# e

# %%
#Imagine that you are working as developer at cricinfo website.
#There is a match going and you have to take the runs scored by
# each player in the team.
# At the end display the entire score card where you display run of each player
#along with team total runs.
#Assume we have 5 player in a team

players = []
sum = 0

for i in range(5):
  p1 = int(input("Enter the player score  = "))
  sum = sum + p1
  players.append(p1)

for p1 in items:
  print(p1)

print(sum)
# Out:
# Enter the player score  = 10
# Enter the player score  = 20
# Enter the player score  = 30
# Enter the player score  = 40
# Enter the player score  = 0
# a
# b
# c
# d
# e
# 100

# %%
#Imagine that you are working as developer at cricinfo website.
#There is a match going and you have to take the runs scored by
# each player in the team.
# At the end display the entire score card where you display run of each player
#along with team total runs.



#Assume we have 5 player in a team
#Dont display all the players run, only Display all the player runs who has scored the centure

players = []
totalZeroScored = []
sum = 0
i = 0


while i < 5:
  p1 = int(input("Enter the player score  = "))
  sum = sum + p1
  players.append(p1)
  i = i+1

if p1 == 0:
  totalZeroScored = totalZeroScored + 1

for i in players:
  if i >= 100:
    print(i)
# Out:
# Enter the player score  = 10
# Enter the player score  = 30
# Enter the player score  = 100
# Enter the player score  = 60
# Enter the player score  = 70
# 100

# %% [markdown]
# <a href="https://colab.research.google.com/github/mkvinay77/azurelib_DE/blob/main/Assignement1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Question 1: A store sells apples at $5 each and bananas at $3 each. Declare variables apples_price and bananas_price with
#appropriate values. Calculate the total cost for purchasing 10 apples and 7 bananas and store the result in total_cost.

# %%
apples_pric = 5
bananas_price = 3

total_apples = apples_pric * 10
total_bananas = bananas_price * 7

grand_total = total_apples + total_bananas
print("The final bill🎉 = ", grand_total,"$")

# %%
# Question 2: You have a monthly salary of $4,000 and expenses that include rent ($1,200), groceries ($300),
# and miscellaneous ($500). Calculate the amount left after expenses and store it in a variable named remaining_balance

# %%
monthly_salary = 4000
#expenses
rent = 1200
grocerie = 300
miscellaneous = 500


#
remaining_balance = (monthly_salary - rent - grocerie - miscellaneous)
print("The remaning amount left after expenses is",remaining_balance,"💲")

# %%
#Question 3: A team won 28 matches this season, and last season they won 18 matches. Declare variables
#current_season_wins and last_season_wins with respective values. Calculate the increase in matches won and store it in win_difference.

# %%
current_season_wins = 28
last_season_win = 18
win_difference = current_season_wins - last_season_win
print("The total number of matches won 🏅🎖️🏅=",win_difference )

# %%
#Question 4: A travel company charges $250 per person for a weekend trip and gives a $100 group
#discount for every 5 people. If a group has 15 people Calculate the total cost for the group and store it in group_trip_cost.

# %%
per_person = 250
people = 15
discount_price = 100
group_size = 5
discount_per_group = 100


discount = (people // group_size) * discount_per_group
group_trip_cost = (per_person * people) - discount
print("The grand total price after discount is =",group_trip_cost,"💲")

# %%
# Question 5: An item costs $120, and there is a discount of 15%. Calculate the final price after the
# discount and store it in discounted_price.

# %%
item_costs = 120
discount = (120*0.15)

discounted_price = item_costs - discount
print("The final dicounted prrice is =",discounted_price,"💲")

# %%
#Question 6: A company produces 500 units daily and sells each unit for $20.
#Declare variables units_per_day and price_per_unit. Calculate the monthly revenue assuming a 30-day month and store it in monthly_revenue.

units_per_day = 500
price_per_unit = 20
number_of_days = 30

monthly_revenue = units_per_day * price_per_unit * number_of_days

print("The total monthly_revenue of the compnay is =",monthly_revenue,"💲")

# %%
#Question 7: A farmer grows wheat on a 150-acre farm and yields 3,000 kg per acre.
#Declare variables acreage and yield_per_acre. Calculate the total wheat production and store it in total_production.
acreage = 150
yields_per_acreage = 3000
total_production = (acreage*yields_per_acreage)
print("The total production 150 acre is =",total_production,"kg")

# %%
#Question 8: A bakery makes $2 profit on each loaf of bread sold. If they sell 200 loaves in a day,
# declare variables profit_per_loaf and loaves_sold. Calculate the daily profit and store it in daily_profit.

profit_per_loaf = 2
loaves_sold = 200
daily_profit = profit_per_loaf * loaves_sold

print("The daily profit is =",daily_profit,"💲")

# %%
#Question 9: You are planning an event for 120 attendees. The venue rental is $800, and catering costs $25
#per person. Declare variables venue_cost, catering_cost_per_person, and number_of_attendees.
#Calculate the total cost of the event and store it in event_total_cost.

venue_cost = 800
catering_cost_per_person = 25
number_of_attendees = 120

event_total_cost = (number_of_attendees * catering_cost_per_person ) + venue_cost
print("The total even cost is =",event_total_cost,"💲")

# %%
#Question 10: A school's annual fee per student is $1,500, and they provide a 5% sibling discount.
#Declare variables annual_fee and sibling_discount_percent. Calculate the discounted fee for one sibling and store it in
#sibling_discounted_fee.

annual_fee = 1500
sibling_discount_percent = 0.05

discounted_amount = annual_fee*sibling_discount_percent
sibling_discounted_fee = annual_fee - discounted_amount

print("The discount price for single sibling is =",sibling_discounted_fee,"💲")

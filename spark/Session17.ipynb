# %%
df = spark.read.csv("/Volumes/workspace/default/batch12-volume/sample data.csv", header=True, inferSchema=True)
display(df)

# %%
df1 = spark.read.csv("/Volumes/workspace/default/batch12-volume/null.txt.txt", header=True, inferSchema=True)
display(df1)

# %%
df2 = df1.na.drop()
display(df2)

# %%
df3 = df1.na.drop("any")
display(df3)

# %%
df4 = df1.na.drop("all")
display(df4)

# %%
df_json = spark.read.json("/Volumes/workspace/default/batch12-volume/Order_JSON.json")
display(df_json)
